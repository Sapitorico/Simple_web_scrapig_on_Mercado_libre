# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import namedtuple
import time
import re
import uuid

# %%
url = "https://listado.mercadolibre.com.uy/auriculares#D[A:auriculares]"
Product = namedtuple('Product', ['id', 'name', 'description', 'price', 'stock', 'category', 'category_id'])

# %%
r = requests.get(url)
html_contents = r.text

# %%
html_soup = BeautifulSoup(html_contents, 'html.parser')
products_links = html_soup.find_all('a', class_='ui-search-item__group__element ui-search-link__title-card ui-search-link')
product_list = []
product_uuid_map = {}
category_uuid_map = {}

# %%
for links in products_links:
    product_url = links.get('href')
    if product_url:
          response = requests.get(product_url)
          product_soup = BeautifulSoup(response.content, 'html.parser', from_encoding='utf-8')
          try:
              name = product_soup.find('h1', class_='ui-pdp-title').text.strip()
          except AttributeError:
              name = "N/A"

          try:
              description = product_soup.find('p', class_='ui-pdp-description__content').text.strip()
          except AttributeError:
              description = "N/A"

          try:
              main_container = product_soup.find('div', class_='ui-pdp-price__main-container')
              price = main_container.find('span', class_='andes-money-amount__fraction').text.strip()
          except AttributeError:
              price = "N/A"

          try:
              stock_text = product_soup.find('span', class_='ui-pdp-buybox__quantity__available').text.strip()
              stock_match = re.search(r'\d+', stock_text)
              stock = stock_match.group(0) if stock_match else "N/A"
          except AttributeError:
              stock = "N/A"

          try:
              categories = product_soup.find_all('a', class_='andes-breadcrumb__link')
              category = categories[-1].text.strip()
          except AttributeError:
              category = "N/A"

          if name not in product_uuid_map:
              product_uuid_map[name] = str(uuid.uuid4())
          product_id = product_uuid_map[name]

          if category not in category_uuid_map:
              category_uuid_map[category] = str(uuid.uuid4())
          category_id = category_uuid_map[category]

          product = Product(product_id, name, description, price, stock, category, category_id)
          product_list.append(product)

          time.sleep(1)

# %%
df = pd.DataFrame(product_list)

df.to_csv('productos.csv', index=False, encoding='utf-8')

print(df)
# Out:
#                                       id  \
# 0   4983acf5-3e20-42e8-8574-957b4fb6f1e7
# 1   e0403173-9c33-4073-9b9d-b8f95832ec2e
# 2   598e19f2-6d1a-4245-858e-ec7683b2e2a7
# 3   2a6d6915-4ddd-44aa-8a9a-33aa085d2be1
# 4   f923e080-6713-4f49-b47e-57e0fb1794a8
# 5   0ce152e9-d3e3-4080-bd02-7bbda935088f
# 6   2b649e67-8a64-41fd-a4e5-644c9e0e8a37
# 7   1aa24ea4-f7eb-4a97-8bc7-585cae9e0cc6
# 8   aa5a4a00-e520-48f2-9985-d60bae5de157
# 9   9b9e9243-d674-4a65-9cab-d83faf5c8ae3
# 10  b58ce56e-b0d4-4f6e-b2b6-e118cbac687f
# 11  cbda4f5d-2367-4ec7-9f28-d9a8ede5eda3
# 12  8872e172-d852-4c25-b6c7-f626fe873d41
# 13  b9a07d85-e0c7-400e-9328-d8250fa72f6d
# 14  d35c856b-742b-46d9-a19a-5f2354a303b0
# 15  f4022168-4d44-421f-bfaf-cdd880af9f21
# 16  f313787f-4f55-4bd5-967b-400d779eaa91
# 17  f5c71351-2be7-4a2c-acda-827d0b818287
# 16  Auriculares In-ear Inalámbricos Sony Wf-c500 C...
# 17  Auriculares Xiaomi Inalámbricos Redmi Buds 4 L...
# 18  Auriculares in-ear inalámbricos JBL Wave JBLV3...
# 19  Auriculares Bluetooth Sony Noise Cancelling Wh...
# 20             Auriculares JBL Tune 500 JBLT500 negro
# 21      Apple EarPods con conector Lightning - Blanco
# 22  Auriculares Bluetooth Inalámbricos In Ear Sony...
# 23  Auriculares gamer Onikuma K5 black y grey con ...
# 24  Auriculares in-ear gamer inalámbricos TWS F9-5...
# 25  Auriculares Inalámbricos Jbl Wave Flex Tws Blu...
# 26  Apple AirPods con estuche de carga (2da genera...
# 27  Auriculares Jbl Inalámbricos - Headphones Flex...
# 28  Auriculares In-ear Inalámbricos Aiwa Aw-twsd4 ...
# 29  Auricular Logitech G332 Gaming 3.5mm Color Neg...
# 30  Auriculares Sony Bluetooth Inalámbricos Wh-ch5...
# 31  Audifono Xiaomi Redmi Buds 4 Active Bluetooth ...
# 32  Auriculares Inalambricos Jbl Tune Flex Negros ...
# 33  Auriculares Bluetooth In-ear Inalámbricos Sony...
# 34  Ultrabook  HP 15-dy2091wm plata 15.6", Intel C...
# 35  Auriculares Inalámbricos Jbl Tune 520 Bt Color...
# 36  Auriculares Con Manos Libres Plug Jack Compati...
# 37  Auriculares Inalámbricos Xiaomi Redmi Buds 4 A...
# 38  Auriculares in-ear gamer inalámbricos Shenzhen...
# 39  Auriculares gamer inalámbricos Logitech G G Se...
# 40  Auriculares Jbl Tune 770nc Black Bluetooth Con...
# 41  Auriculares in-ear gamer inalámbricos Shenzhen...
# 42                  Apple AirPods Pro (2ª generación)
# 43  Auricular Bluetooth Xion Inalámbrico Vincha Co...
# 44       Auriculares in-ear JBL Tune 110 JBLT110 blue
# 45              Auriculares In-ear Jbl Tune 110 Negro
# 46  Auriculares Sony Bluetooth Inalámbricos Wh-ch5...
# 47  Apple AirPods (3ª generación) con estuche de c...
# 48  Auriculares Bluetooth Inalámbricos Sony WF-100...
# 49  Auriculares In-ear Inalámbricos Jbl Wave Buds ...
#
#                                           description  price stock  \
# 0   En la calle, en el colectivo o en la oficina, ...    314    20
# 1   Los auriculares Xiaomi Redmi Bud Essential ofr...    849    50
# 2   JBL, marca de renombre mundial en el mercado d...     49    50
# 3   ¡Experimentá la adrenalina de sumergirte en la...     85    50
# 4   Sony, sin lugar a dudas es una de las marcas m...     54    10
# 5   JBL, marca de renombre mundial en el mercado d...     52   N/A
# 6   JBL, marca de renombre mundial en el mercado d...     81    20
# 7   Xiaomi, marca de origen china nacida en 2010 e...    869    10
# 8   ¡Experimentá la adrenalina de sumergirte en la...     66    20
# 9   En la calle, en el colectivo o en la oficina, ...  1.299    50
# 10  Auriculares Sony Bluetooth Inalámbricos WH-CH5...     55    50
# 11  JBL, marca de renombre mundial en el mercado d...     71     2
# 12  ¡Experimentá la adrenalina de sumergirte en la...  1.138     4
# 13  JBL, marca de renombre mundial en el mercado d...     85     4
# 14  JBL, marca de renombre mundial en el mercado d...     52    20
# 15  ¡Experimentá la adrenalina de sumergirte en la...     99    50
# 16  Sony, sin lugar a dudas es una de las marcas m...     99    10
# 17  Sumérgete en la experiencia sonora que te brin...     26    10
# 18  JBL, marca de renombre mundial en el mercado d...     75    50
# 19  Auriculares Bluetooth Sony Noise Cancelling Wh...    336    10
# 20  JBL, marca de renombre mundial en el mercado d...     29   N/A
# 21  A diferencia de los audífonos circulares tradi...  1.190    50
# 22  Sony, sin lugar a dudas es una de las marcas m...     32    50
# 23  ¡Experimentá la adrenalina de sumergirte en la...    770    50
# 24  ¡Experimentá la adrenalina de sumergirte en la...    350    20
# 25  Lleva tu sonido a todas partes. Con unos bajos...     71    50
# 26  Los AirPods te brindan una experiencia inalámb...    121     5
# 27  JBL, marca de renombre mundial en el mercado d...    104    50
# 28  Auriculares In-ear Inalámbricos Aiwa Aw-twsd4 ...     34    20
# 29  ¡Experimenta la adrenalina de sumergirte en la...     59     5
# 30  Sony, sin lugar a dudas es una de las marcas m...     52     5
# 31  ¡Experimenta la adrenalina de sumergirte en la...     35    50
# 32  JBL, marca de renombre mundial en el mercado d...     99    10
# 33  Sony, sin lugar a dudas es una de las marcas m...    122    10
# 34  Aviso legal• La duración de la batería depende...    529    50
# 35  JBL, marca de renombre mundial en el mercado d...     52    50
# 36  Estos auriculares manos libres Plug Jack, de c...    100    50
# 37  Xiaomi, marca de origen china nacida en 2010 e...     23    50
# 38  ¡Experimentá la adrenalina de sumergirte en la...    350    50
# 39  ¡Experimentá la adrenalina de sumergirte en la...    108    50
# 40  PRODUCTO:Nombre: Audifonos JBL Tune 770 BT Hea...    109     5
# 41  ¡Experimentá la adrenalina de sumergirte en la...    335    10
# 42  Los AirPods Pro vienen con hasta 2 veces más C...    259     3
# 43  En la calle, en el colectivo o en la oficina, ...     29    10
# 44  JBL, marca de renombre mundial en el mercado d...     15     5
# 45  En la calle, en el colectivo o en la oficina, ...    402    50
# 46  Auriculares Sony Bluetooth Inalámbricos WH-CH5...     54    10
# 47  Presentamos los nuevos AirPods. Con audio espa...    259   N/A
# 48  Los Auriculares Bluetooth Inalámbricos Sony Wf...    299    10
# 49  JBL, marca de renombre mundial en el mercado d...     60    50
#
#         category                           category_id
# 0    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 1   Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 2    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 3    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 4    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 5    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 6    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 7   Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 8    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 9    Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 10   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 11   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 12  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 13   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 14   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 15   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 16   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 17  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 18   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 19   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 20   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 21  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 22   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 23   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 24   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 25   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 26  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 27   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 28   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 29   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 30   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 31  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 32   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 33   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 34     Notebooks  8fb86826-2dd6-4988-ac03-b2c23e7be452
# 35   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 36  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 37   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 38   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 39   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 40   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 41   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 42  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 43   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 44   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 45   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 46   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 47  Manos Libres  3f8dff24-d955-4778-9ae3-e369fa1025e9
# 48   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
# 49   Auriculares  dc96757d-456f-46ae-928b-6ff36a7a111c
